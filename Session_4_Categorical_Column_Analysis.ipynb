# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#path=r"C:\Users\subra\Documents\NareshIT\datafiles\Visadataset.csv"
csv_path=r"C:\Users\subra\Documents\NareshIT\datafiles\Visadataset.csv"
visa_df=pd.read_csv(csv_path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **prevailing_wage**

# %% [markdown]
# - len
# - max
# - min
# - mean
# - median
# - 25percentile
# - 50percentile
# - 75percentile

# %%
wage_data=visa_df['prevailing_wage']
len(wage_data)
# Out:
# 25480

# %%
wage_data=visa_df['prevailing_wage']
min(wage_data)
# Out:
# 2.1367

# %%
wage_data=visa_df['prevailing_wage']
max(wage_data)
# Out:
# 319210.27

# %%
wage_data=visa_df['prevailing_wage']
wage_data.mean()
# Out:
# np.float64(74455.81459209183)

# %%
wage_data=visa_df['prevailing_wage']
wage_data.median(),np.median(wage_data)
# Out:
# (70308.20999999999, np.float64(70308.20999999999))

# %% [markdown]
# **Quantile and percentile**

# %%
p_25=np.percentile(wage_data,25)
p_25
# Out:
# np.float64(34015.479999999996)

# %%
p_50=np.percentile(wage_data,50)
p_50
# Out:
# np.float64(70308.20999999999)

# %%
p_75=np.percentile(wage_data,75)
p_75
# Out:
# np.float64(107735.51250000001)

# %%
q_25=np.quantile(wage_data,0.25)
q_25
# Out:
# np.float64(34015.479999999996)

# %%
q_50=np.quantile(wage_data,0.50)
q_50
# Out:
# np.float64(70308.20999999999)

# %%
q_50=np.quantile(wage_data,0.75)
q_50
# Out:
# np.float64(107735.51250000001)

# %%
wage_data=visa_df['prevailing_wage']
wage_count=len(wage_data)
wage_min=round(wage_data.min(),2)
wage_max=round(wage_data.max(),2)
wage_mean=round(wage_data.mean(),2)
wage_median=round(wage_data.median(),2)
wage_25p=round(np.percentile(wage_data,25),2)
wage_50p=round(np.percentile(wage_data,50),2)
wage_75p=round(np.percentile(wage_data,75),2)

l=[wage_count,wage_min,wage_max,wage_mean,wage_median,wage_25p,wage_50p,wage_75p]
id=['count','min','max','mean','median','25p','50p','75p']
pd.DataFrame(l,id,columns=['value'])
# Out:
#             value
# count    25480.00
# min          2.14
# max     319210.27
# mean     74455.81
# median   70308.21
# 25p      34015.48
# 50p      70308.21
# 75p     107735.51

# %%
L=[]
for i in num:
    data=visa_df[i]
    count=len(wage_data)
    min=round(wage_data.min(),2)
    max=round(wage_data.max(),2)
    mean=round(wage_data.mean(),2)
    median=round(wage_data.median(),2)
    p_25=round(np.percentile(wage_data,25),2)
    p_50=round(np.percentile(wage_data,50),2)
    p_75=round(np.percentile(wage_data,75),2)
    l=[count,min,max,mean,median,p_25,p_50,p_75]
    id=['count','min','max','mean','median','p_25','p_50','p_75']
    L.append(l)    
df=pd.DataFrame(L,index=num,columns=id)
df
# Out:
#                  count   min        max      mean    median      p_25  \
# no_of_employees  25480  2.14  319210.27  74455.81  70308.21  34015.48
# yr_of_estab      25480  2.14  319210.27  74455.81  70308.21  34015.48
# prevailing_wage  25480  2.14  319210.27  74455.81  70308.21  34015.48
#
#                      p_50       p_75
# no_of_employees  70308.21  107735.51
# yr_of_estab      70308.21  107735.51
# prevailing_wage  70308.21  107735.51

# %%
df.T
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# min                2.14         2.14             2.14
# max           319210.27    319210.27        319210.27
# mean           74455.81     74455.81         74455.81
# median         70308.21     70308.21         70308.21
# p_25           34015.48     34015.48         34015.48
# p_50           70308.21     70308.21         70308.21
# p_75          107735.51    107735.51        107735.51

# %% [markdown]
# **describe func**

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile concept**
#
# - 250 : 25 percentage of data below 25p value
# - wage_25p = 34015.48
#     - there 25*(25480)/100=6370 applicants have less then 34015.48
# - wage_50p = 70308.21
#     - there 50*(25480)/100=12740 applicants have less then 70308.21
# - wage_75p = 107735.51
#     - there 75*(25480)/100=19110 applicants have less then 107735.51

# %%
con=visa_df['prevailing_wage']<wage_25p
len(visa_df[con]),len(visa_df)*25/100
len(visa_df[con])==len(visa_df)*25/100
# Out:
# True

# %%
con=visa_df['prevailing_wage']<wage_50p
len(visa_df[con]),len(visa_df)*50/100
len(visa_df[con])==len(visa_df)*50/100
# Out:
# True

# %%
con=visa_df['prevailing_wage']<wage_75p
len(visa_df[con]),len(visa_df)*75/100
len(visa_df[con])==len(visa_df)*75/100
# Out:
# True

# %%
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Emperical rule**
#
# - u-1*sigma  to  u+1*sigma 68%
# - step-1 : wage data mean(u)
# - step-2 : wage data std (sigma)
# - step-3 : LB=u-1*sigma
# - step-4 : LB=u+1*sigma
# - step-5 : con1=visa_df['prevailing_wage']>LB
# - step-6 : con2=visa_df['prevailing_wage']<LB
# - step-7 : con=con1&con2
# - step-8 : len(visa_df[con])

# %%
u=wage_data.mean()
u
# Out:
# np.float64(74455.81459209183)

# %%
s=wage_data.std()
s
# Out:
# 52815.94232687357

# %%
LB=u-1*s
LB
# Out:
# np.float64(21639.872265218262)

# %%
LB1=u+1*s
LB1
# Out:
# np.float64(127271.7569189654)

# %%
con1=visa_df['prevailing_wage']>LB
con1
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
con2=visa_df['prevailing_wage']<LB1
con2
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
con=con1&con2
con
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
len(visa_df[con])
# Out:
# 17171

# %%
u=wage_data.mean()
s=wage_data.std()
LB=u-1*s
LB1=u+1*s
con1=visa_df['prevailing_wage']>LB
con2=visa_df['prevailing_wage']<LB1
con=con1&con2
len(visa_df[con])
len(visa_df[con])==68*25480/100
# Out:
# False

# %% [markdown]
# **conclusion : Emperical rule failed wage data does not follow Normal distribution**

# %%
68*25480/100
# Out:
# 17326.4

# %%
97*25480/100
# Out:
# 24715.6

# %%
len(visa_df[con])==68*25480/100
# Out:
# False

# %% [markdown]
# ## Histogram

# %%
plt.hist(wage_data,bins=10)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
inter_counts,inter_vals,n=plt.hist(wage_data,bins=10)

# %%
inter_counts   # frequency interval
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
inter_vals     # class interval
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
n
# Out:
# <BarContainer object of 10 artists>

# %%
lb=2.13670000e+00
ub=3.19229500e+04
con1=visa_df['prevailing_wage']>=lb
con2=visa_df['prevailing_wage']<=ub
con=con1&con2
len(visa_df[con])
# Out:
# 6038

# %% [markdown]
# **Outlier Analysis**

# %% [markdown]
# - we understand emperical rule failed
# - then we plotted histogram its slightly deviated
# - so it indicates the data has outlier
# - outlier can show by **Box plot**
#
# -                         code-block:: none
#
#           Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                        |-----:-----|
#        o      |--------|     :     |--------|    o  o
#                        |-----:-----|
#      flier             <----------->            fliers
#                             IQR

# %% [markdown]
# ## Box Plot

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.show()

# %% [markdown]
# **outliers data**

# %%
# q1
# q2
# q3
# IQR=q3-q1
# UB =q3+1.5*IQR
# LB =q1-1.5*IQR
# con1= wage > UB
# con2= wage < LB
# con = con1 / con2   Outlier


# if we use And operators
# con1= wage < UB
# con2= wage > LB
# con3 = con1 & con2

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q1-1.5*IQR
#for outlier
con1=wage_data>ub
con2=wage_data<lb
f_con1=con1|con2
print(len(wage_data[f_con1]))

con3=wage_data<ub
con4=wage_data>lb
f_con2=con3&con4
print(len(wage_data[f_con2]))


total=len(wage_data[f_con1])+len(wage_data[f_con2])
print(total)
# Out:
# 427
# 25053
# 25480

# %%
outliers_df=visa_df[f_con1]
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **fill the outliers**

# %% [markdown]
# - drop the outlier
# - fill with mwdian
# - winsorization : fill with LB and UB

# %%
# con1=wage_data>ub
# con2=wage_data<lb
# f_con1=con1|con2
# outlier=wage_data[f_con1]
# we will iterate each value from wage data
# if the value match

# %%
outliers=outliers_df['prevailing_wage'].values.tolist()
l=[]
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
for value in wage_data:
    if value in outliers:
        l.append(wage_med)
    else:
        l.append(value)
visa_df['prevailing_wage1']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
print(wage_data)
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage1'],vert=False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
IQR=(q3-q1)
ub=q3+1.5*IQR
lb=q1-1.5*IQR
visa_df['prevailing_wage2'] = visa_df['prevailing_wage'].clip(lower=lb, upper=ub)

visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status  \
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage2'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage2'],vert=False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.show()

# %%
import numpy as np
import pandas as pd
Data={ 'Name':['Ramesg','Suresh','Sathish',np.nan],
      'Age':[np.nan,22,25,27],
      'City':['Pune','Pune',np.nan,'Hyd']}
df=pd.DataFrame(Data)
df
# Out:
#       Name   Age  City
# 0   Ramesg   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %%
import numpy as np
import pandas as pd
Data={ 'Name':['Ramesg','Suresh','Sathish',None],
      'Age':[None,22,25,27],
      'City':['Pune','Pune',None,'Hyd']}
df1=pd.DataFrame(Data)
df1
# Out:
#       Name   Age  City
# 0   Ramesg   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  None
# 3     None  27.0   Hyd

# %%
import numpy as np
import pandas as pd
Data={ 'Name':['Ramesg','Suresh','Sathish',Null],
      'Age':[Null,22,25,27],
      'City':['Pune','Pune',Null,'Hyd']}
df2=pd.DataFrame(Data)
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 Data={ 'Name':['Ramesg','Suresh','Sathish',Null],
#       4       'Age':[Null,22,25,27],
#       5       'City':['Pune','Pune',Null,'Hyd']}
#       6 df2=pd.DataFrame(Data)
#       7 df2
#
# NameError: name 'Null' is not defined

# %%
import numpy as np
import pandas as pd
Data={ 'Name':['Ramesg','Suresh','Sathish',null],
      'Age':[null,22,25,27],
      'City':['Pune','Pune',null,'Hyd']}
df3=pd.DataFrame(Data)
df3

# %%
df.to_csv('data_missing.csv',index=False)

# %%
df1.to_csv('data_missing1.csv',index=False)

# %%
df.dtypes
# Out:
# Name     object
# Age     float64
# City     object
# dtype: object

# %%
df1.dtypes
# Out:
# Name     object
# Age     float64
# City     object
# dtype: object

# %% [markdown]
# **isnull**

# %%
df.isnull()
# Out:
#     Name    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df1.isnull()
# Out:
#     Name    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df.isnull().sum()
# Out:
# Name    1
# Age     1
# City    1
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Name    1
# Age     1
# City    1
# dtype: int64

# %% [markdown]
# **fillna**

# %%
df.fillna(30)  # not recomended
# Out:
#       Name   Age  City
# 0   Ramesg  30.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0    30
# 3       30  27.0   Hyd

# %%
df['Age'].fillna(30)
# Out:
# 0    30.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %% [markdown]
# - the above one is we are filling randomly
# - all the columns are filled with random number
# - it is not a good approach because in  a data we have different data types

# %%
df['Age'].fillna(30,inplace=True)
df
# Out:
# C:\Users\subra\AppData\Local\Temp\ipykernel_13092\3801372385.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(30,inplace=True)
#       Name   Age  City
# 0   Ramesg  30.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %% [markdown]
# **What is the difference between np.nan and None**

# %%
np.nan+5
# Out:
# nan

# %%
None+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 None+5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1=np.array([1,2,np.nan,3])
arr2=np.array([1,2,None,3])

# %%
arr1
# Out:
# array([ 1.,  2., nan,  3.])

# %%
arr2
# Out:
# array([1, 2, None, 3], dtype=object)

# %%
np.nansum(arr1),np.sum(arr1)
# Out:
# (np.float64(6.0), np.float64(nan))

# %%
np.sum(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 np.sum(arr2)
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# - np.nan represent **float type**
# - None represents **Object type**
# - If the data operations related to maths then nan format is better

# %% [markdown]
# **Fill the value based on a specific column**

# %%
df['Name'].fillna('Amit')
# Out:
# 0     Ramesg
# 1     Suresh
# 2    Sathish
# 3       Amit
# Name: Name, dtype: object

# %% [markdown]
# **Fill with methods**
# - whenever we are using methods no need to provide values

# %%
import numpy as np
import pandas as pd
Data={ 'Name':['Ramesg','Suresh','Sathish',np.nan],
      'Age':[np.nan,22,25,27],
      'City':['Pune','Pune',np.nan,'Hyd']}
df=pd.DataFrame(Data)
df
# Out:
#       Name   Age  City
# 0   Ramesg   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %% [markdown]
# - pad
# - bfill
# - ffill
# - backfill

# %%
# import warnings
# warnings.filterwarnings('ignore')
df.fillna(method='pad')
# Out:
# C:\Users\subra\AppData\Local\Temp\ipykernel_13092\2558497203.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#       Name   Age  City
# 0   Ramesg   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  Pune
# 3  Sathish  27.0   Hyd

# %% [markdown]
# **Note**
# - to avoid warning
# - we  import warnings
# - warnings.filterwarnings('ignore')

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad')  # column wise
# Out:
#       Name   Age  City
# 0   Ramesg   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  Pune
# 3  Sathish  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad',axis=1)      # row wise
# Out:
#       Name     Age  City
# 0   Ramesg  Ramesg  Pune
# 1   Suresh    22.0  Pune
# 2  Sathish    25.0  25.0
# 3      NaN    27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='bfill')
# Out:
#       Name   Age  City
# 0   Ramesg  22.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   Hyd
# 3      NaN  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='ffill')
# Out:
#       Name   Age  City
# 0   Ramesg   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  Pune
# 3  Sathish  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='backfill')
# Out:
#       Name   Age  City
# 0   Ramesg  22.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   Hyd
# 3      NaN  27.0   Hyd

# %% [markdown]
# **Note**
# - pad=ffill
# - bfill=backfill

# %%
age_mean=df['Age'].mean()
df['Age'].fillna(age_mean)
# Out:
# 0    24.666667
# 1    22.000000
# 2    25.000000
# 3    27.000000
# Name: Age, dtype: float64

# %%
age_median=df['Age'].median()
df['Age'].fillna(age_median)
# Out:
# 0    25.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %%
city_mode=df['City'].mode()
df['City'].fillna(city_mode)
# Out:
# 0    Pune
# 1    Pune
# 2     NaN
# 3     Hyd
# Name: City, dtype: object

# %%
city_mode
# Out:
# 0    Pune
# Name: City, dtype: object

# %%
mode=df['City'].mode()
mode
# Out:
# 0    Pune
# Name: City, dtype: object

# %% [markdown]
# **KNN Immputer**
# - K-Nearest Neighbours
# - Where K = hyper parameter which means the user can change
# - Idea: Instead of taking all the samples average
#     - First fix the neighbours number i.e k
#     - Then find the neighbours using distance matric
#     - Then take the average of those samples to fill the missing value

# %%
# import sklearn
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.preprocessing import LabelEncoder
# from sklearn.impute import KNNImputer

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
pd.DataFrame(X)
# Out:
#      0     1    2
# 0  1.0   2.0  NaN
# 1  3.0   NaN  3.0
# 2  NaN  60.0  5.0
# 3  8.0   8.0  7.0

# %%
# import method
# save method
# apply fit_transform

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
imputer = KNNImputer(n_neighbors=2,
                    weights='uniform')
imputer.fit_transform(X)
# Out:
# array([[ 1. ,  2. ,  5. ],
#        [ 3. , 31. ,  3. ],
#        [ 5.5, 60. ,  5. ],
#        [ 8. ,  8. ,  7. ]])

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
imputer = KNNImputer(n_neighbors=2,
                    weights='distance')
imputer.fit_transform(X)
# Out:
# array([[ 1.        ,  2.        ,  3.93905505],
#        [ 3.        , 31.        ,  3.        ],
#        [ 3.25775362, 60.        ,  5.        ],
#        [ 8.        ,  8.        ,  7.        ]])

# %% [markdown]
# ==================EDA steps ===================
# - 1.Read the data
# - 2.Separate categorical  column and Numerical column
# - 3.Data quick check
#     - Shape, column, dtypes
# - 4.Null value Analysis
#     - A) Check if any Null Values are present
#     - B) Fill the null values with Median or
#           KNNImputer for Numerical column
#     - C) Fill the null values with Mode for categorical columns
# - 5.Do some data  preprocess if any column is corrupted
#     - ex1: Numerical values in categorical column
#     - ex2: Categorical values in Numerical column
# - 6.Drop the ID type columns
#     - which means a data has more unique labels
#     - Drop the single value column
# - 7.Categorical column Analysis
#     - Frequency table
#     - Bar chart
#     - pie chart
# - 8.Numerical column Analysis
#     - Histogram
#     - Distribution
#     - Box plot
# - 9.Outlier Analysis
#     - Impute the outlier with Median
# - 10.Find the corelation between numerical columns
#     - Heat map
# - 11.Convert Categorical to Numerical
#     - A) Label Encoder
#     - B) one Hot Encoder
# - 12.Scale the data
#     - A) Z standardaization
#     - B) Normalization
#
# **Note**
# - By performing 12 steps , We achive 3 things
#     - i. Cleaned the data
#     - ii. Data in the form of complete  numerical
#     - iii. We have some outstanding data
#
# - 13.We will try to select the important feature For ML Model
#     - A) PCA : Principal component analysis (Covered in ML)
# - Finally we achive 3 data sets
#     - 1. Till Step-11
#          with out scale but data in Numerical format
#     - 2. Till Step-12
#          With scaling data in Numerical format
#     - 3. Till Step-13
#          PCA data
